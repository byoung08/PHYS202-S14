# %% [markdown]
# # "ODE Exercises".

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Question 1
#
# For this question refer to the solutions for the nonlinear pendulum we got using scipy's odeint from the beginning of the ODE Tour.
#
# (a) Use the numerical solution to see what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs. t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 or π ?

# %%
g = 9.8 #m/s**2
ell = 0.5 #m

th0 = [0, pi/4, pi/2, 3*pi/4, pi]


def deriv(theta_current,t):  #return derivatives of the array theta
    g = 9.8 #m/s^2
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([ dtheta, domega ])


t = np.arange(0.,10.+0.01,0.01)

omega0 = 0.  #starting from rest, omega = 0


theta_init0 = np.array([th0[0], omega0]) #initial values, th0 from befor = 20 degrees radian
theta0 = odeint(deriv, theta_init0, t)

theta_init1 = np.array([th0[1], omega0])
theta1 = odeint(deriv, theta_init1, t)

theta_init2 = np.array([th0[2], omega0])
theta2 = odeint(deriv, theta_init2, t)

theta_init3 = np.array([th0[3], omega0])
theta3 = odeint(deriv, theta_init3, t)

theta_init4 = np.array([th0[4], omega0])
theta4 = odeint(deriv, theta_init4, t)




plt.plot(t,theta0[:,0],'b',label="Angle = 0 ")
plt.plot(t,theta1[:,0],'g',label="Angle = pi/4")
plt.plot(t,theta2[:,0],'r',label="Angle = pi/2")
plt.plot(t,theta3[:,0],'orange',label="Angle = 3pi/4")
plt.plot(t,theta4[:,0],'black',label="Angle = pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-3.,4.0)
plt.grid()
plt.legend(loc="lower left", bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
g = 9.8 #m/s**2
ell = 0.5 #m

th0 = .95*pi


def deriv(theta_current,t):  #return derivatives of the array theta
    g = 9.8 #m/s^2
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([ dtheta, domega ])


t = np.arange(0.,10.+0.01,0.01)

omega0 = 0.  #starting from rest, omega = 0


theta_init = np.array([th0, omega0]) #initial values, th0 from befor = 20 degrees radian
theta = odeint(deriv, theta_init, t)

plt.plot(t,theta[:,0], 'r', label=r'$\theta $')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)

plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(t,theta[:,1], 'b')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)

plt.grid()
plt.title(r'$\omega$ vs t', fontsize = 20)
plt.show()

# %%
plt.plot(theta[:,0],theta[:,1], 'b')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad)$',fontsize=20)

plt.grid()
plt.title(r'$\omega$ vs theta', fontsize = 20)
plt.show()

# %% [markdown]
# c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓ(1−cos(θ))+12ℓ2ω2 ).

# %% [markdown]
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
theta = odeint(deriv, theta_init, t)
Em =  g*ell*(1-np.cos(theta[:,0])) + .5*ell**2*theta[:,1]**2
plt.plot(t, Em, 'r')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel('Energy',fontsize=20)
plt.ylim(0,11)
plt.grid()
plt.title('Energy vs time', fontsize = 20)
plt.show()

# %% [markdown]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
g = 9.8 #m/s**2
ell = 0.5 #m

th0 = pi
t = np.arange(0.,50.+0.01,0.01)

omega0 = 0.  
theta_init = np.array([th0, omega0]) #initial values, th0 from befor = 20 degrees radian
theta = odeint(deriv, theta_init, t)

plt.plot(t,theta[:,0], 'r')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)

plt.grid()
plt.title('theta vs time')
plt.show()

# %% [markdown]
# **Question 2**
#
#
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.

# %% [markdown]
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %%
def EulerFreefall(dx):
    xmax = 2 # maximum time
    
    
    nsteps = int(xmax/dx)
   
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    F = x + 2*y
 
    # set initial conditions, redundant in this example
    t[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
       
        y[i+1] = y[i] + dx * (x[i] + 2*y[i])
        
    return x,y

# %%
xe,ye = EulerFreefall(.25)



from scipy.interpolate import interp1d
interp = interp1d(xe,ye)

x1 = 1
y1 = interp(x1)

plt.plot(xe,ye,x1,y1,'b+', markersize=20, markeredgewidth=2)
plt.plot(xe,ye,'r-', label= "y(t)")
plt.title("dx = .25")
plt.annotate(y1, xy = (x1,y1), xytext=(1,1))
plt.grid()
plt.show()

# %%
xe1,ye1 = EulerFreefall(.02)



from scipy.interpolate import interp1d
interp = interp1d(xe1,ye1)

x1 = 1
y1 = interp(x1)

plt.plot(xe1,ye1,x1,y1,'b+', markersize=20, markeredgewidth=2)
plt.plot(xe1,ye1,'r-', label= "y(t)")
plt.title("dx = .02")
plt.annotate(y1, xy = (x1,y1), xytext=(1,2))
plt.grid()
plt.show()

# %% [markdown]
# (b) Plot the results from part (a) for the two different step sizes with the exact solution
# y=0.25e2x−0.5x−0.25
# on one plot. Include a legend. Which step size gives a more accurate result?

# %%
true = 0.25*exp(2*xe1)-0.5*xe1-0.25


plt.plot(xe,ye,'b',label = 'dx=.25')
plt.plot(xe1,ye1,'r-', label= "dx=.02")
plt.plot(xe1,true,"orange", label = 'true solution')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %% [markdown]
# (c) Now solve the same problem using Euler-Cromer and the Midpoint method for the same pair of step sizes and plot the results along with the exact solution. Then also plot the difference between the approximate numerical solutions and the exact solution. Which combination of method and step-size gives the best result?

# %%
def EulerCromerFreefall(dx):
    xmax = 2
    
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    F = x + 2*y
 
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
       
        y[i+1] = y[i] + dx * (x[i+1] +2*y[i+1]) #use just calculated v value to compute y
        
    return x,y

# %%
xe,ye = EulerCromerFreefall(.25)
xe1,ye1 = EulerCromerFreefall(.02)




true = 0.25*exp(2*xe1)-0.5*xe1-0.25


plt.plot(xe,ye,'b',label = 'dx=.25')
plt.plot(xe1,ye1,'r-', label= "dx=.02")
plt.plot(xe1,true,"orange", label = 'true solution')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %%
err = true - ye1
plt.plot(xe1,true,"orange", label = 'Euler - Cromer error of dx=0.2')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %%
def mid(dx):
    xmax = 2
    
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    F = x + 2*y
    
     # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
       
        y[i+1] = y[i] + dx * (x[i+1] +2*y[i+1]) #use just calculated v value to compute y
        
    return x,y

# %%
xe,ye = mid(.25)
xe1,ye1 = mid(.02)

true = 0.25*exp(2*xe1)-0.5*xe1-0.25


plt.plot(xe,ye,'b',label = 'dx=.25')
plt.plot(xe1,ye1,'r-', label= "dx=.02")
plt.plot(xe1,true,"orange", label = 'true solution')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %%
err = true - ye1
plt.plot(xe1,true,"orange", label = 'Euler - Cromer error of dx=0.2')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far it can travel in the x direction before landing.

# %%
def der(y,t):
    vector = y[4]
    g = 9.8
    vx = y[0]
    vy = y[2]
    m= 1
    y2 = y[3]
    x2 = y[1]
    
    
    dvxdt = -g/m * vx/vector**2 * sqrt(vx**2+vy**2)
    dvydt = -g/m * (1 + vy/vector**2 * sqrt(vx**2+vy**2))
    
    
    return np.array([dvxdt, vx, dvydt, vy])

# %%
vx0 = 30* np.cos(50./180.*np.pi)
vy0 = 30* np.sin(50./180.*np.pi)
v0= 30
x0= 0
y0 = 0
vter = 44
t = np.arange(0., 200.+0.1,0.1)



answer = odeint(der, np.array([vx0,x0,vy0,y0,vter]),t)

vx = answer[:,0]
vy = answer[:,2]

plt.plot(t,vx,'b',label = 'velocity in x')
plt.plot(t, vy,'r-', label= "velocity in y")
plt.ylabel('velocity m/s')
plt.xlabel('time(s)')
plt.legend(loc='upper center')
plt.grid()
plt.show()

# %%
x = answer[:,1]
y = answer[:,3]

plt.plot(x,y)
plt.ylabel('y-axis displacement' )
plt.xlabel('x-axis displacement')
plt.xlim(0,100)
plt.ylim(-5,25)
plt.title("projectile trajectory")
plt.grid()
plt.show()

# %% [markdown]
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:

# %%
from IPython.html.widgets import interact, interactive

# %%
def Projectile(v0, vterm, th0, time, y0):
    g = 9.8
    vx0 = v0 * np.cos(th0*np.pi/180.)
    x0 = 0
    vy0 = v0 * np.sin(th0*np.pi/180.)
    t = np.arange(0., time+0.001, 0.001)
    
    init = np.array([vx0,x0,vy0,y0,vterm])
    print vx0, vy0
    answer = odeint(der, init, t)

    vx = answer[:,0]
    vy = answer[:,2]
    x = vx *t
    y = vy *t
    xt = x0 + vx*t
    yt = y0 +vy*t - .5*g*t**2
    
    
    plt.plot(x,y, label="without drag")
    plt.plot(xt,yt, label = "with drag")
    
    
    plt.ylabel('y-axis displacement' )
    plt.xlabel('x-axis displacement')
    plt.xlim(0,100)
    
    plt.ylim(0,45)
    plt.legend()
    plt.title("projectile trajectory")
    plt.grid()
    plt.show()
    
v = interact(Projectile, v0=(0,100,1),vterm=(0,110,1), th0=(0,90,1), time= (0,200,1),y0=(0,1.5,0.1))
# Out:
# 63.6396103068 63.6396103068

# %%
# %%file theTable.py

object    terminal vel    initial height  initial vel  initial angle


golfball     44 m/s              0 m         90 m/s       45deg
baseball     43 m/s             1.5 m        94 m/s       45deg 
pumpkin      107 m/s            1.5 m        52 m/s       45deg
# Out:
# Writing theTable.py

# %%
# !more theTable.py
# Out:
# object    terminal vel    initial height  initial vel  initial angle
#
#
# golfball     44 m/s              0 m         90 m/s       45deg
# baseball     43 m/s             1.5 m        94 m/s       45deg
# pumpkin      107 m/s            1.5 m        52 m/s       45deg
