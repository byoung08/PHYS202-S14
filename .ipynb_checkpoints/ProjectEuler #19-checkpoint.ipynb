# %% [markdown]
# Counting Sundays
#
# You are given the following information, but you may prefer to do some research for yourself.
#
# 1 Jan 1900 was a Monday.
#
# Thirty days has September,
#
# April, June and November.
#
# All the rest have thirty-one,
#
# Saving February alone,
#
# Which has twenty-eight, rain or shine.
#
# And on leap years, twenty-nine.
#
# A leap year occurs on any year evenly divisible by 4, but not on a century unless it is divisible by 400.
# How many Sundays fell on the first of the month during the twentieth century (1 Jan 1901 to 31 Dec 2000)?

# %%
year = {}
days = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']

week_day = 1
count = 0

for yr in range(1901, 2001):
    if yr % 4 == 0:
        for day in range(1,367):
            year[day] = days[week_day]
            week_day += 1
            if week_day == 7:
                week_day = 0
                
                
        if year[1] == 'sunday': #january
            count += 1
        if year[32] == 'sunday':   #febuary
            count += 1
        if year[61] == 'sunday':  #march
            count += 1
        if year[92] == 'sunday':  #april
            count += 1
        if year[122] == 'sunday':   #may
            count += 1
        if year[153] == 'sunday':     #june
            count += 1
        if year[183] == 'sunday':   #july
            count += 1
        if year[214] == 'sunday':   #august
            count += 1
        if year[245] == 'sunday':   #september
            count += 1
        if year[275] == 'sunday':    #october
            count += 1
        if year[306] == 'sunday':     #november
            count += 1
        if year[336] == 'sunday':      #december
            count += 1
        year = {}
            
    else:
        for day in range(1,366):
            year[day] = days[week_day]
            week_day += 1
            if week_day == 7:
                week_day = 0
        if year[1] == 'sunday': #january
            count += 1
        if year[32] == 'sunday':   #febuary
            count += 1
        if year[60] == 'sunday':  #march
            count += 1
        if year[91] == 'sunday':  #april
            count += 1
        if year[121] == 'sunday':   #may
            count += 1
        if year[152] == 'sunday':     #june
            count += 1
        if year[182] == 'sunday':   #july
            count += 1
        if year[213] == 'sunday':   #august
            count += 1
        if year[244] == 'sunday':   #september
            count += 1
        if year[274] == 'sunday':    #october
            count += 1
        if year[305] == 'sunday':     #november
            count += 1
        if year[335] == 'sunday':      #december
            count += 1


    year = {}
    
    
   
print count
# Out:
# 171
